# %%
import pandas as pd
import glob
import os

# %%
path = r'C:\Users\winba\Desktop\TYP_ALT\model_training\data\new_sep_data' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f) for f in all_files)
concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
concatenated_df.head()
# Out:
#    hands  fingers  lh_palm_pos_x  lh_palm_pos_y  lh_palm_pos_z  rh_palm_pos_x  \
# 0      1        5      25.053236     202.452866      49.622128      25.053236
# 1      1        5      24.645641     206.540268      41.572113      24.645641
# 2      1        5      23.973083     205.467682      35.499435      23.973083
# 3      1        5      23.227406     203.595459      31.620090      23.227406
# 4      1        5      22.855707     202.868973      30.578320      22.855707
#
#    rh_palm_pos_y  rh_palm_pos_z  lh_normal_x  lh_normal_y  ...  \
# 0     202.452866      49.622128    -0.996186    -0.064425  ...
# 1     206.540268      41.572113    -0.999296    -0.032818  ...
# 2     205.467682      35.499435    -0.999347    -0.019041  ...
# 3     203.595459      31.620090    -0.999424    -0.009476  ...
# 4     202.868973      30.578320    -0.999545    -0.007429  ...
#
#    rh_thumb_tip_x  rh_thumb_tip_y  rh_thumb_tip_z  rh_thumb_velocity_x  \
# 0      -27.312109      236.585480       50.465893          -149.853073
# 1      -28.309689      241.472473       42.329967          -101.109657
# 2      -29.249521      241.000320       36.793579            57.258919
# 3      -29.937248      239.777451       33.788124            20.431316
# 4      -30.254816      239.216034       33.118156            13.274804
#
#    rh_thumb_velocity_y  rh_thumb_velocity_z  rh_wrist_pos_x  rh_wrist_pos_y  \
# 0           295.140472          -332.295044       35.700832      144.642014
# 1            84.686287          -116.710693       34.277878      149.869797
# 2             6.461397          -147.844574       32.346989      147.557861
# 3             6.911358           -65.111595       30.931044      144.746780
# 4           -20.927277           -49.084957       30.493473      143.698029
#
#    rh_wrist_pos_z  label
# 0       89.025169   zero
# 1       83.581245   zero
# 2       76.242531   zero
# 3       71.313721   zero
# 4       69.935051   zero
#
# [5 rows x 141 columns]

# %%
concatenated_df.shape
# Out:
# (52901, 141)

# %%
concatenated_df.to_csv('data/new_combined_data.csv', index=False)
